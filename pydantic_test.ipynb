# %%
from pydantic import BaseModel

class std(BaseModel):
    name:str
    age:int
    dept:str
    
std=std(
    name="Vasantha leela M",
    age=21,
    dept="AI"
)

print(std)
# Out:
# name='Vasantha leela M' age=21 dept='AI'

# %%
from pydantic import BaseModel

class std(BaseModel):
    name:str
    age:int
    dept:str

std=std(
    name="Vasantha leela M",
    age="Hello",
    dept="AI"
)

print(std)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[7], line 8
#       5     age:int
#       6     dept:str
# ----> 8 std=std(
#       9     name="Vasantha leela M",
#      10     age="Hello",
#      11     dept="AI"
#      12 )
#      14 print(std)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\pydantic\main.py:253, in BaseModel.__init__(self, **data)
#     251 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     252 __tracebackhide__ = True
# --> 253 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     254 if self is not validated_self:
#     255     warnings.warn(
#     256         'A custom validator is returning a value other than `self`.\n'
# ...
